# %% [markdown]
# <a href="https://colab.research.google.com/github/asdsadawww/-/blob/main/Colab_%ED%8C%8C%EC%9D%B4%EC%8D%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab 시작 페이지

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')        #내 기본 시작 모듈
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
score=[80,60,70,50,90]
score
# Out:
# [80, 60, 70, 50, 90]

# %%
sum(score)
# Out:
# 350

# %%
sum_score=sum(score)

# %%
sum_score
# Out:
# 350

# %%
df=pd.DataFrame({'name'    :['김지훈','이유진','박동현','김민지'],
                 'english' :[90,80,60,70],
                 'math'    :[50,60,100,20]})
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
sum(df['english'])
# Out:
# 300

# %%
sum(df['math'])
# Out:
# 230

# %%
sum(df['english'])/4
# Out:
# 75.0

# %%
sum(df['math'])/4
# Out:
# 57.5

# %%
df=pd.DataFrame({'제품'   :['사과','딸기','수박'],
                 '가격'   :[1800,1500,3000],
                 '판매량' :[24,38,13]})
df
# Out:
#    제품    가격  판매량
# 0  사과  1800   24
# 1  딸기  1500   38
# 2  수박  3000   13

# %%
sum(df['가격'])
# Out:
# 6300

# %%
sum(df['가격'])/3
# Out:
# 2100.0

# %%
sum(df['판매량'])
# Out:
# 75

# %%
sum(df['판매량'])/3
# Out:
# 25.0

# %%
df_exam = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/exam.csv')
df_exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
sum(df_exam['english']) # 총 합
# Out:
# 1698

# %%
sum(df_exam['english'])/20 # 총 20명
# Out:
# 84.9

# %%
sum(df_exam['science'])/20
# Out:
# 59.45

# %%
df=pd.DataFrame({'a':[1,2,3],
                 'b':[4,5,6]})

# %%
df
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
len(df)
# Out:
# 3

# %%
len(df_exam)   #df_exam 행의 개수
# Out:
# 20

# %%
sum(df_exam['english'])/len(df_exam['english'])   #영어 평균
# Out:
# 84.9

# %%
sum(df_exam['science'])/len(df_exam['science'])   #과학 평균
# Out:
# 59.45

# %%
df_midterm=pd.DataFrame({'english' :[90,80,60,70],
                         'math'    :[50,60,100,20],
                         'nclass'  :[1,1,2,2]})
df_midterm
# Out:
#    english  math  nclass
# 0       90    50       1
# 1       80    60       1
# 2       60   100       2
# 3       70    20       2

# %%
df_midterm.to_csv('output_newdata.csv')

# %%
exam=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/exam.csv')

# %%
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.shape
# Out:
# (20, 5)

# %%
exam.describe()
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %%
mpg=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/mpg.csv')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/exam.csv')
df.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_raw=pd.DataFrame({'var1' :[1,2,1],
                     'var2' :[2,3,2]})
df_raw
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %%
df=pd.DataFrame({'var1' :[4,3,8],
                 'var2' :[2,6,1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df['var_sum']=df['var1']+df['var2']
df
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df['var_mean']=(df['var1']+df['var2'])/2
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
mpg['total']=(mpg['cty']+mpg['hwy']) /2  #통합연비 변수만들기
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
sum(mpg['total'])/ len(mpg)  #total합계를 행 수로 나누기
# Out:
# 20.14957264957265

# %%
mpg['total'].mean()   #통합연비 변수 평균(이게 더 간결하고 좋음)
# Out:
# np.float64(20.14957264957265)

# %%
mpg['total'].describe() #요약 통계량
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg['total'].plot.hist() #히스토그램(값의 빈도를 막대길이로 표현한 그래프)
# Out:
# <Axes: ylabel='Frequency'>

# %%
mpg['test']=np.where(mpg['total']>=20,'pass','fail') #연비가 20이상이면 pass 아니면 fail
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test
# 0   23.5  pass
# 1   25.0  pass
# 2   25.5  pass
# 3   25.5  pass
# 4   21.0  pass

# %%
mpg['test'].value_counts() #연비 합격 빈도 표
# Out:
# test
# pass    128
# fail    106
# Name: count, dtype: int64

# %%
count_test=mpg['test'].value_counts() #빈도표를 변수로 만듦, 코드 가독성 높임

# %%
count_test.plot.bar()   #연비 합격 빈도를 막대그래프로
# Out:
# <Axes: xlabel='test'>

# %%
count_test.plot.bar(rot=0) #축 이름을 수평으로 만듦
# Out:
# <Axes: xlabel='test'>

# %%
mpg['grade']=np.where(mpg['total'] >= 30,'A',
             np.where(mpg['total'] >= 20,'B','C'))
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test grade
# 0   23.5  pass     B
# 1   25.0  pass     B
# 2   25.5  pass     B
# 3   25.5  pass     B
# 4   21.0  pass     B

# %%
count_grade=mpg['grade'].value_counts()       #등급별 빈도표
count_grade
# Out:
# grade
# B    118
# C    106
# A     10
# Name: count, dtype: int64

# %%
count_grade.plot.bar(rot=0)
# Out:
# <Axes: xlabel='grade'>

# %%
count_grade=mpg['grade'].value_counts().sort_index()      #등급별 빈도표, 알파벳순으로 정렬됨
count_grade
# Out:
# grade
# A     10
# B    118
# C    106
# Name: count, dtype: int64

# %%
count_grade.plot.bar(rot=0)
# Out:
# <Axes: xlabel='grade'>

# %%
mpg['size']=np.where(mpg['class'].isin(['compact','subcompact','2seater']), 'small', 'large')
mpg['size'].value_counts()       #데이터에있는  ↑ class에 차들을 큰차 작은차로 나눔 compact,subcompact, 2seater가 포함되면 small로 분류
# Out:
# size
# large    147
# small     87
# Name: count, dtype: int64

# %%
exam=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/exam.csv')
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass==1')        #nclass가 1인 학생들의 데이터만 추출
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass==2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('nclass!=1')            #nclass가 1이 아닌것들만 출력
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass!=3')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('english>50')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('math>=50')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass==1&math>=50')               #여러조건을 동시에 충족할 때 & 기호를 사
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.query('nclass==1 | nclass==3 | nclass==5')   #여러조건중 하나라도 충족할 때 | 기호를 사용
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass in [1,3,5]')           #nclass가 1,3,5에 해당하면 추출함
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.sort_values('math')   #math오름차순으로 정렬
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %%
exam.sort_values('math',ascending=False)         #내림차순 정렬 ascending=false 에서 ascending은 오름차순이라는 뜻
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 0    1       1    50       98       50
# 5    6       2    50       89       98
# 9   10       3    50       98       45
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
exam.sort_values(['nclass','math'])             #nclass와math를 오름차순 정렬 []를 추가해 변수 지정하면 됨
# Out:
#     id  nclass  math  english  science
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 11  12       3    45       85       32
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 19  20       5    78       83       58
# 17  18       5    80       78       90
# 18  19       5    89       68       87

# %%
exam.sort_values(['nclass','math'],ascending=[True,False])   #nclass오름차순 math내림차순 정렬 ascending칸 지정한 열의 순서와 1대1로 일치함
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 8    9       3    20       98       15
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 16  17       5    65       68       98

# %%
mpg.query('manufacturer=="audi"').sort_values('hwy',ascending=False).head() #audi생산 자동차 중 1~5위에 해당하는 높은연비를 가진 자동차 데이터
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
#
#      class  total  test grade   size
# 2  compact   25.5  pass     B  small
# 3  compact   25.5  pass     B  small
# 1  compact   25.0  pass     B  small
# 0  compact   23.5  pass     B  small
# 9  compact   24.0  pass     B  small

# %%
exam.assign(total=exam['math']+exam['english']+exam['science'])          #파생변수 total추가
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
exam.assign(total=exam['math']+exam['english']+exam['science']).assign(mean=(exam['math']+exam['english']+exam['science'])/3) #total(합계)과 mean(평균)추가
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# ...

# %%
exam.assign(test=np.where(exam['science']>=60,'pass','fail')) #60점 이하의 science과목 pass fail여부
# Out:
#     id  nclass  math  english  science  test
# 0    1       1    50       98       50  fail
# 1    2       1    60       97       60  pass
# 2    3       1    45       86       78  pass
# 3    4       1    30       98       58  fail
# 4    5       2    25       80       65  pass
# 5    6       2    50       89       98  pass
# 6    7       2    80       90       45  fail
# 7    8       2    90       78       25  fail
# 8    9       3    20       98       15  fail
# 9   10       3    50       98       45  fail
# 10  11       3    65       65       65  pass
# 11  12       3    45       85       32  fail
# 12  13       4    46       98       65  pass
# 13  14       4    48       87       12  fail
# 14  15       4    75       56       78  pass
# 15  16       4    58       98       65  pass
# 16  17       5    65       68       98  pass
# 17  18       5    80       78       90  pass
# 18  19       5    89       68       87  pass
# 19  20       5    78       83       58  fail

# %%
exam.assign(total=exam['math']+exam['english']+exam['science']).sort_values('total') #total변수 추가와 오름차순 정렬
# Out:
#     id  nclass  math  english  science  total
# 8    9       3    20       98       15    133
# 13  14       4    48       87       12    147
# 11  12       3    45       85       32    162
# 4    5       2    25       80       65    170
# 3    4       1    30       98       58    186
# 9   10       3    50       98       45    193
# 7    8       2    90       78       25    193
# 10  11       3    65       65       65    195
# 0    1       1    50       98       50    198
# 12  13       4    46       98       65    209
# 14  15       4    75       56       78    209
# 2    3       1    45       86       78    209
# 6    7       2    80       90       45    215
# 1    2       1    60       97       60    217
# 19  20       5    78       83       58    219
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 5    6       2    50       89       98    237
# 18  19       5    89       68       87    244
# ...

# %%
mpg_new=mpg.copy()
mpg_new=mpg_new.assign(total=mpg_new['cty']+mpg_new['hwy']) #mpg_new를 2번사용하는이유(덮어쓰기를 해야 이전assign값을 가져오지 않음)

# %%
mpg_new=mpg_new.assign(mean=mpg_new['total']/2) #평균연비구함

# %%
mpg_new.sort_values('mean',ascending=False).head(3) #오름차순과 제일 높은 값3개구함
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class  total  test grade   size  mean
# 221  subcompact     79  pass     A  small  39.5
# 212     compact     77  pass     A  small  38.5
# 222  subcompact     70  pass     A  small  35.0

# %%
exam.agg(mean_math=('math','mean'))  #math평균구함
# Out:
#             math
# mean_math  57.45

# %%
exam.groupby('nclass').agg(mean_math=('math','mean')) #nclass별로 분리하고 math평균 구
# Out:
#         mean_math
# nclass
# 1           46.25
# 2           61.25
# 3           45.00
# 4           56.75
# 5           78.00

# %%
exam.groupby('nclass',as_index=False).agg(mean_math=('math','mean')) #엑셀 표 형태같이 일반 데이터 열로 유지해서 출력함
# Out:
#    nclass  mean_math
# 0       1      46.25
# 1       2      61.25
# 2       3      45.00
# 3       4      56.75
# 4       5      78.00

# %%
exam.groupby('nclass').agg(mean_math=('math','mean'),sum_math=('math','sum'),median_math=('math','median'),n=('nclass','count')) #nclass별로 분리, 수학점수 평균, 합계, 중앙값, 학생 수(빈도)
# Out:
#         mean_math  sum_math  median_math  n
# nclass
# 1           46.25       185         47.5  4
# 2           61.25       245         65.0  4
# 3           45.00       180         47.5  4
# 4           56.75       227         53.0  4
# 5           78.00       312         79.0  4

# %%
exam.groupby('nclass').mean()     #변수 요약 통계량을 한꺼번에 구함
# Out:
#           id   math  english  science
# nclass
# 1        2.5  46.25    94.75    61.50
# 2        6.5  61.25    84.25    58.25
# 3       10.5  45.00    86.50    39.25
# 4       14.5  56.75    84.75    55.00
# 5       18.5  78.00    74.25    83.25

# %%
mpg.groupby(['manufacturer','drv']).agg(mean_cty=('cty','mean')) #제조 회사 및 구동 방식별 분리, cty평균 구함
# Out:
#                    mean_cty
# manufacturer drv
# audi         4    16.818182
#              f    18.857143
# chevrolet    4    12.500000
#              f    18.800000
#              r    14.100000
# dodge        4    12.000000
#              f    15.818182
# ford         4    13.307692
#              r    14.750000
# honda        f    24.444444
# hyundai      f    18.642857
# jeep         4    13.500000
# land rover   4    11.500000
# lincoln      r    11.333333
# mercury      4    13.250000
# nissan       4    13.750000
#              f    20.000000
# pontiac      f    17.000000
# subaru       4    19.285714
# toyota       4    14.933333
#              f    21.368421
# volkswagen   f    20.925926

# %%
mpg.query('manufacturer=="audi"').groupby(['drv']).agg(n=('drv','count')) #audi의 drv별 빈도
# Out:
#       n
# drv
# 4    11
# f     7

# %%
mpg.query('manufacturer=="chevrolet"').groupby(['drv']).agg(n=('drv','count')) #chevrolet의 drv별 빈도
# Out:
#       n
# drv
# 4     4
# f     5
# r    10

# %%
mpg['drv'].value_counts() #집단별 빈도를 간단하게 구하
# Out:
# drv
# f    106
# 4    103
# r     25
# Name: count, dtype: int64

# %%
mpg.query('`class`=="suv"').assign(total=(mpg['hwy']+mpg['cty'])/2).groupby('manufacturer').agg(mean_tot=('total','mean')).sort_values('mean_tot',ascending=False).head()
# Out:
#                mean_tot
# manufacturer
# subaru        21.916667
# toyota        16.312500
# nissan        15.875000
# mercury       15.625000
# jeep          15.562500

# %%
mpg.groupby('class').agg(mean_cty=('cty','mean'))   #class별 cty평균
# Out:
#              mean_cty
# class
# 2seater     15.400000
# compact     20.127660
# midsize     18.756098
# minivan     15.818182
# pickup      13.000000
# subcompact  20.371429
# suv         13.500000

# %%
mpg.groupby('class').agg(mean_cty=('cty','mean')).sort_values('mean_cty',ascending=False) #내림차순정렬
# Out:
#              mean_cty
# class
# subcompact  20.371429
# compact     20.127660
# midsize     18.756098
# minivan     15.818182
# 2seater     15.400000
# suv         13.500000
# pickup      13.000000

# %%
mpg.groupby('class').agg(mean_cty=('cty','mean')).sort_values('mean_cty',ascending=False).head(3)
# Out:
#              mean_cty
# class
# subcompact  20.371429
# compact     20.127660
# midsize     18.756098

# %%
mpg.query('`class`=="compact"').groupby('manufacturer').agg(n=('manufacturer','count')).sort_values('n',ascending=False)  #1번째
# Out:
#                n
# manufacturer
# audi          15
# volkswagen    14
# toyota        12
# subaru         4
# nissan         2

# %%
mpg.query('`class`=="compact"').value_counts('manufacturer')  #2번째 / value_counts로 집단별 빈도를 더 간단히 구할수있음. 빈도를 구할 변수를 추출한 다음 적용하면 됨
# Out:
# manufacturer
# audi          15
# volkswagen    14
# toyota        12
# subaru         4
# nissan         2
# Name: count, dtype: int64

# %%
test1 = pd.DataFrame({'id' : [1, 2, 3, 4, 5],
                    'midterm':[60,80,70,90,85]})

test2 = pd.DataFrame({'id' : [1, 2, 3, 4, 5],
                    'final':[70,83,65,95,80]})

# %%
test1
# Out:
#    id  midterm
# 0   1       60
# 1   2       80
# 2   3       70
# 3   4       90
# 4   5       85

# %%
test2
# Out:
#    id  final
# 0   1     70
# 1   2     83
# 2   3     65
# 3   4     95
# 4   5     80

# %%
total=pd.merge(test1,test2,how='left',on='id')               #id기준으로  total할당함 on이 id인 이유는 공통 기준 열을 맞추기 위해
total
# Out:
#    id  midterm  final
# 0   1       60     70
# 1   2       80     83
# 2   3       70     65
# 3   4       90     95
# 4   5       85     80

# %%
name=pd.DataFrame({'nclass':[1,2,3,4,5],
                   'teacher':['kim','lee','park','choi','jung']})
name
# Out:
#    nclass teacher
# 0       1     kim
# 1       2     lee
# 2       3    park
# 3       4    choi
# 4       5    jung

# %%
exam_new=pd.merge(exam,name,how='left',on='nclass')     #nclass기준으로 합치고 exam_new에 할당함
exam_new
# Out:
#     id  nclass  math  english  science teacher
# 0    1       1    50       98       50     kim
# 1    2       1    60       97       60     kim
# 2    3       1    45       86       78     kim
# 3    4       1    30       98       58     kim
# 4    5       2    25       80       65     lee
# 5    6       2    50       89       98     lee
# 6    7       2    80       90       45     lee
# 7    8       2    90       78       25     lee
# 8    9       3    20       98       15    park
# 9   10       3    50       98       45    park
# 10  11       3    65       65       65    park
# 11  12       3    45       85       32    park
# 12  13       4    46       98       65    choi
# 13  14       4    48       87       12    choi
# 14  15       4    75       56       78    choi
# 15  16       4    58       98       65    choi
# 16  17       5    65       68       98    jung
# 17  18       5    80       78       90    jung
# 18  19       5    89       68       87    jung
# ...

# %%
group_a=pd.DataFrame({'id' : [1,2,3,4,5],
                      'test':[60,80,70,90,85]})
group_b=pd.DataFrame({'id': [6,7,8,9,10],
                      'test':[70,83,65,95,80]})

# %%
group_a
# Out:
#    id  test
# 0   1    60
# 1   2    80
# 2   3    70
# 3   4    90
# 4   5    85

# %%
group_b
# Out:
#    id  test
# 0   6    70
# 1   7    83
# 2   8    65
# 3   9    95
# 4  10    80

# %%
group_all=pd.concat([group_a,group_b])
group_all
# Out:
#    id  test
# 0   1    60
# 1   2    80
# 2   3    70
# 3   4    90
# 4   5    85
# 0   6    70
# 1   7    83
# 2   8    65
# 3   9    95
# 4  10    80

# %%
fuel=pd.DataFrame({'fl'       : ['c','d','e','p','r'],
                   'price_fl' : [2.35,2.38,2.11,2.76,2.22]})
fuel
# Out:
#   fl  price_fl
# 0  c      2.35
# 1  d      2.38
# 2  e      2.11
# 3  p      2.76
# 4  r      2.22

# %%
mpg=pd.merge(mpg,fuel,how='left',on='fl')

# %%
mpg[['model','fl','price_fl']].head()
# Out:
#   model fl  price_fl
# 0    a4  p      2.76
# 1    a4  p      2.76
# 2    a4  p      2.76
# 3    a4  p      2.76
# 4    a4  p      2.76

# %%
df=pd.DataFrame({'sex'   : ['M','F',np.nan,'M','F'],
                 'score' : [5,4,3,4,np.nan]})
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df['score']+1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# 4    NaN
# Name: score, dtype: float64

# %%
 pd.isna(df) #결측치 확인
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
pd.isna(df).sum()  #결측치 빈도 확인
# Out:
# sex      1
# score    1
# dtype: int64

# %%
df.dropna(subset='score') #score의 결측치 제거
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df_nomiss=df.dropna(subset='score')         #score결측치 제거된 데이터
df_nomiss['score']+1                        #score로 연산함
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# Name: score, dtype: float64

# %%
df_nomiss=df.dropna(subset=['score','sex'])    #score,sex 결측치 제거
df_nomiss
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df_nomiss2=df.dropna()         #모든 변수에 결측치 없는데이터로
df_nomiss2
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
exam.loc[[2,7,14],['math']]=np.nan          #2, 7, 14행의 math에 NaN
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam['math'].mean()
# Out:
# np.float64(55.23529411764706)

# %%
exam['math']=exam['math'].fillna(55)         #math가 NaN이면 55로 대체함
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1  55.0       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2  55.0       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4  55.0       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam['math'].isna().sum()        #결측치 검사
# Out:
# np.int64(0)

# %%
mpg.loc[[64,123,130,152,211], 'hwy']=np.nan

# %%
mpg[['drv','hwy']].isna().sum()
# Out:
# drv    0
# hwy    5
# dtype: int64

# %%
mpg.dropna(subset=['hwy']).groupby('drv').agg(mean_hwy=('hwy','mean'))    #변수 결측치 제거, 구동방식 hwy 평균조사
# Out:
#       mean_hwy
# drv
# 4    19.242424
# f    28.200000
# r    21.000000

# %%
df=pd.DataFrame({'sex'   :[1,2,1,3,2,1],
                 'score' :[5,4,3,4,2,6]})
df
# Out:
#    sex  score
# 0    1      5
# 1    2      4
# 2    1      3
# 3    3      4
# 4    2      2
# 5    1      6

# %%
df['sex'].value_counts().sort_index()
# Out:
# sex
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
df['score'].value_counts().sort_index()
# Out:
# score
# 2    1
# 3    1
# 4    2
# 5    1
# 6    1
# Name: count, dtype: int64

# %%
df['sex']=np.where(df['sex']==3,np.nan,df['sex'])       #sex가 3이면 NaN부여함
df
# Out:
#    sex  score
# 0  1.0      5
# 1  2.0      4
# 2  1.0      3
# 3  NaN      4
# 4  2.0      2
# 5  1.0      6

# %%
df['score']=np.where(df['score']>5,np.nan,df['score'])       #score가 5보다 크면 NaN부여함
df
# Out:
#    sex  score
# 0  1.0    5.0
# 1  2.0    4.0
# 2  1.0    3.0
# 3  NaN    4.0
# 4  2.0    2.0
# 5  1.0    NaN

# %%
df.dropna(subset=['sex','score']).groupby('sex').agg(mean_score=('score','mean'))   #sex, score 결측치 제거, sex별 분리, score평균 구
# Out:
#      mean_score
# sex
# 1.0         4.0
# 2.0         3.0

# %%
sns.boxplot(data=mpg, y='hwy')
# Out:
# <Axes: ylabel='hwy'>

# %%
pct25=mpg['hwy'].quantile(.25)
pct25
# Out:
# np.float64(18.0)

# %%
pct75=mpg['hwy'].quantile(.75)
pct75
# Out:
# np.float64(27.0)

# %%
iqr=pct75-pct25
iqr
# Out:
# np.float64(9.0)

# %%
pct25-1.5*iqr   #하한
# Out:
# np.float64(4.5)

# %%
pct75+1.5*iqr    #상한
# Out:
# np.float64(40.5)

# %%
mpg = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/mpg.csv')
mpg['hwy']=np.where((mpg['hwy']<4.5) | (mpg['hwy']>40.5),np.nan, mpg['hwy'])           #4.5~40.5를 벗어나면 NaN부여함
mpg['hwy'].isna().sum()                                                                #결측치 빈도 확인함
# Out:
# np.int64(3)

# %%
mpg.dropna(subset='hwy').groupby('drv').agg(mean_hwy=('hwy','mean'))         #결측치 제거, drv별 분리, hwy별 평균 구하기
# Out:
#       mean_hwy
# drv
# 4    19.174757
# f    27.728155
# r    21.000000

# %%
mpg=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/mpg.csv')
mpg.loc[[9,13,57,92],'drv']='k'
mpg.loc[[28,42,128,202],'cty']=[3,4,39,42]

# %%
mpg['drv'].value_counts().sort_index()
#이상치 확인
# Out:
# drv
# 4    100
# f    106
# k      4
# r     24
# Name: count, dtype: int64

# %%
mpg['drv']=np.where(mpg['drv'].isin(['4','f','r']),mpg['drv'],np.nan)
#drv가 4, f, r이면 기존 값 유지함, 그 외엔 NaN부여함

# %%
mpg['drv'].value_counts().sort_index()
# Out:
# drv
# 4    100
# f    106
# r     24
# Name: count, dtype: int64

# %%
sns.boxplot(data=mpg,y='cty')
# Out:
# <Axes: ylabel='cty'>

# %%
pct25=mpg['cty'].quantile(.25)     #1사분위수
pct75=mpg['cty'].quantile(.75)     #3사분위수
iqr=pct75-pct25                    #IQR

# %%
pct25-1.5*iqr   #하한
# Out:
# np.float64(6.5)

# %%
pct75+1.5*iqr   #상한
# Out:
# np.float64(26.5)

# %%
mpg['cty']=np.where((mpg['cty']<6.5)|(mpg['cty']>26.5),np.nan,mpg['cty'])      #6.5 ~ 26.5 벗어나면 NaN부여함

# %%
sns.boxplot(data=mpg,y='cty')       #상자그래프 출력
# Out:
# <Axes: ylabel='cty'>

# %%
mpg.dropna(subset=['drv','cty']).groupby('drv').agg(mean_cty=('cty','mean'))    #drv, cty결측치 제거, drv별 분리, cty평균 구함
# Out:
#       mean_cty
# drv
# 4    14.247423
# f    19.470000
# r    13.958333

# %%
mpg=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/mpg.csv')

# %%
sns.scatterplot(data=mpg, x='displ',y='hwy')     # x축은 displ, y축은 hwy를 나타내는 산점도
# Out:
# <Axes: xlabel='displ', ylabel='hwy'>

# %%
sns.scatterplot(data=mpg, x='displ',y='hwy').set(xlim=[3,6])      # x축 범위를 3-6으로 제한함
# Out:
# [(3.0, 6.0)]

# %%
sns.scatterplot(data=mpg, x='displ',y='hwy').set(xlim=[3,6],ylim=[10,30])      # x축 범위를 3-6으로 제한, y축 범위를 10-30ㅡㅇ로 제한함
# Out:
# [(3.0, 6.0), (10.0, 30.0)]

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', hue='drv')   #drv별로 표시 색깔을 다르게 변경
# Out:
# <Axes: xlabel='displ', ylabel='hwy'>

# %%
plt.rcParams.update({'figure.dpi' : '150'})           #해상도, 기본값 72
plt.rcParams.update({'figure.figsize' :[8,6]})        #가로, 세로 크기 기본값 [6,4]
plt.rcParams.update({'font.size' :'15'})              #글자 크기,  기본값 10
plt.rcParams.update({'font.family' :'Malgun Gothic'}) #폰트, 기본값 sans-serif

# %%
plt.rcdefaults()     #그래프 모든 설정 되돌림

# %%
sns.scatterplot(data=mpg, x='cty',y='hwy')
# Out:
# <Axes: xlabel='cty', ylabel='hwy'>

# %%
midwest=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/midwest.csv')

# %%
sns.scatterplot(data=midwest, x='poptotal',y='popasian').set(xlim=[0,500000],ylim=[0,10000])          #산점도 만들고, x축, y축 제한
# Out:
# [(0.0, 500000.0), (0.0, 10000.0)]

# %%
df_mpg=mpg.groupby('drv').agg(mean_hwy=('hwy','mean'))        #drv별 분리, hwy평균
df_mpg
# Out:
#       mean_hwy
# drv
# 4    19.174757
# f    28.160377
# r    21.000000

# %%
df_mpg=mpg.groupby('drv',as_index=False).agg(mean_hwy=('hwy','mean'))        #drv별 분리, hwy평균
df_mpg
# Out:
#   drv   mean_hwy
# 0   4  19.174757
# 1   f  28.160377
# 2   r  21.000000

# %%
sns.barplot(data=df_mpg,x='drv',y='mean_hwy',hue='drv')      #막대그래프로 출력
# Out:
# <Axes: xlabel='drv', ylabel='mean_hwy'>

# %%
df_mpg=df_mpg.sort_values('mean_hwy',ascending=False)       #이 코드가 먼저 와야됨, 정렬하기
sns.barplot(data=df_mpg,x='drv',y='mean_hwy',hue='drv')
# Out:
# <Axes: xlabel='drv', ylabel='mean_hwy'>

# %%
df_mpg=mpg.groupby('drv',as_index=False).agg(n=('drv','count'))         #집단별 빈도표
df_mpg
# Out:
#   drv    n
# 0   4  103
# 1   f  106
# 2   r   25

# %%
sns.barplot(data=df_mpg,x='drv',y='n',hue='drv')
# Out:
# <Axes: xlabel='drv', ylabel='n'>

# %%
mpg['drv'].unique()
# Out:
# array(['f', '4', 'r'], dtype=object)

# %%
df_mpg['drv'].unique()
# Out:
# array(['4', 'f', 'r'], dtype=object)

# %%
sns.countplot(data=mpg,x='drv',order=['4','f','r'])        # 4, f, r순으로 막대정렬
# Out:
# <Axes: xlabel='drv', ylabel='count'>

# %%
mpg['drv'].value_counts().index             #drv의 값을 빈도가 높은순으롱ㄹ
# Out:
# Index(['f', '4', 'r'], dtype='object', name='drv')

# %%
df=mpg.query('`class`=="suv"').groupby('manufacturer',as_index=False).agg(mean_cty=('cty','mean')).sort_values('mean_cty',ascending=False).head()
df
#suv차종 추출, manufacturer별 분리, cty평균 구하기, 내림차순 정렬, 상위 5행 표시
# Out:
#   manufacturer   mean_cty
# 8       subaru  18.833333
# 9       toyota  14.375000
# 7       nissan  13.750000
# 3         jeep  13.500000
# 6      mercury  13.250000

# %%
sns.barplot(data=df, x='manufacturer',y='mean_cty',hue='manufacturer')
# Out:
# <Axes: xlabel='manufacturer', ylabel='mean_cty'>

# %%
df_mpg=mpg.groupby('class',as_index=False).agg(n=('class','count')).sort_values('n',ascending=False)
df_mpg
#category별 분리, 빈도 구하기, 내림차순 정렬
# Out:
#         class   n
# 6         suv  62
# 1     compact  47
# 2     midsize  41
# 5  subcompact  35
# 4      pickup  33
# 3     minivan  11
# 0     2seater   5

# %%
sns.barplot(data=df_mpg,x='class',y='n',hue='class')
# Out:
# <Axes: xlabel='class', ylabel='n'>

# %%
economics=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/economics.csv')
economics.head()
# Out:
#          date    pce       pop  psavert  uempmed  unemploy
# 0  1967-07-01  506.7  198712.0     12.6      4.5      2944
# 1  1967-08-01  509.8  198911.0     12.6      4.7      2945
# 2  1967-09-01  515.6  199113.0     11.9      4.6      2958
# 3  1967-10-01  512.2  199311.0     12.9      4.9      3143
# 4  1967-11-01  517.4  199498.0     12.8      4.7      3066

# %%
sns.lineplot(data=economics,x='date',y='unemploy')           #선 그래프로 표시 date변수에 원래 연/월/일 이 있는데 X축 가로로 여러변 겹쳐 표시되어 굵은 선으로 보임
# Out:
# <Axes: xlabel='date', ylabel='unemploy'>

# %%
#날짜 시간 타입 변수 만듦
economics['date2']=pd.to_datetime(economics['date'])
#변수 타입 확인
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      574 non-null    object
#  1   pce       574 non-null    float64
#  2   pop       574 non-null    float64
#  3   psavert   574 non-null    float64
#  4   uempmed   574 non-null    float64
#  5   unemploy  574 non-null    int64
#  6   date2     574 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 31.5+ KB

# %%
economics[['date','date2']]
# Out:
#            date      date2
# 0    1967-07-01 1967-07-01
# 1    1967-08-01 1967-08-01
# 2    1967-09-01 1967-09-01
# 3    1967-10-01 1967-10-01
# 4    1967-11-01 1967-11-01
# ..          ...        ...
# 569  2014-12-01 2014-12-01
# 570  2015-01-01 2015-01-01
# 571  2015-02-01 2015-02-01
# 572  2015-03-01 2015-03-01
# 573  2015-04-01 2015-04-01
#
# [574 rows x 2 columns]

# %%
economics['date2'].dt.year #연 추출
# Out:
# 0      1967
# 1      1967
# 2      1967
# 3      1967
# 4      1967
#        ...
# 569    2014
# 570    2015
# 571    2015
# 572    2015
# 573    2015
# Name: date2, Length: 574, dtype: int32

# %%
economics['date2'].dt.month #월 추출
# Out:
# 0       7
# 1       8
# 2       9
# 3      10
# 4      11
#        ..
# 569    12
# 570     1
# 571     2
# 572     3
# 573     4
# Name: date2, Length: 574, dtype: int32

# %%
economics['date2'].dt.day #일 추출
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 569    1
# 570    1
# 571    1
# 572    1
# 573    1
# Name: date2, Length: 574, dtype: int32

# %%
economics['year']=economics['date2'].dt.year     #연도 변수 추가
economics.head()
# Out:
#          date    pce       pop  psavert  uempmed  unemploy      date2  year
# 0  1967-07-01  506.7  198712.0     12.6      4.5      2944 1967-07-01  1967
# 1  1967-08-01  509.8  198911.0     12.6      4.7      2945 1967-08-01  1967
# 2  1967-09-01  515.6  199113.0     11.9      4.6      2958 1967-09-01  1967
# 3  1967-10-01  512.2  199311.0     12.9      4.9      3143 1967-10-01  1967
# 4  1967-11-01  517.4  199498.0     12.8      4.7      3066 1967-11-01  1967

# %%
sns.lineplot(data=economics,x='year',y='unemploy')   # X축에 연도 표시
# Out:
# <Axes: xlabel='year', ylabel='unemploy'>

# %%
sns.lineplot(data=economics,x='year',y='unemploy',errorbar=None)       #신뢰구간 제거(선의 위아래에 표시된 면적 제거)
# Out:
# <Axes: xlabel='year', ylabel='unemploy'>

# %%
sns.lineplot(data=economics,x='year',y='psavert')
# Out:
# <Axes: xlabel='year', ylabel='psavert'>

# %%
#월 변수 추가
economics['month']=economics['date2'].dt.month
#2014년 추출
df_2014=economics.query('year==2014')
#선 그래프 만듦
sns.lineplot(data=df_2014,x='month', y='psavert',errorbar=None)
# Out:
# <Axes: xlabel='month', ylabel='psavert'>

# %%
sns.boxplot(data=mpg,x='drv',y='hwy',hue='drv')
# Out:
# <Axes: xlabel='drv', ylabel='hwy'>

# %%
#compact, subcompact, suv 차종 추출
df=mpg.query('`class` in ["compact","subcompact","suv"]')
#상자그림 생성
sns.boxplot(data=df,x='class',y='cty',hue='class')
# Out:
# <Axes: xlabel='class', ylabel='cty'>

# %%
pip install pyreadstat

# %%
pip install jpype1

# %%
pip install konlpy

# %%
moon=open('/content/drive/MyDrive/Colab Notebooks/speech_moon.txt',encoding='UTF-8').read()
moon
# Out:
# '정권교체 하겠습니다!\n  정치교체 하겠습니다!\n  시대교체 하겠습니다!\n  \n  ‘불비불명(不飛不鳴)’이라는 고사가 있습니다. 남쪽 언덕 나뭇가지에 앉아, 3년 동안 날지도 울지도 않는 새. 그러나 그 새는 한번 날면 하늘 끝까지 날고, 한번 울면 천지를 뒤흔듭니다.\n\n그 동안 정치와 거리를 둬 왔습니다. 그러나 암울한 시대가 저를 정치로 불러냈습니다. 더 이상 남쪽 나뭇가지에 머무를 수 없었습니다. 이제 저는 국민과 함께 높이 날고 크게 울겠습니다. 오늘 저는 제18대 대통령선거 출마를 국민 앞에 엄숙히 선언합니다.\n\n\n‘우리나라 대통령’이 되겠습니다.\n\n\n존경하는 국민 여러분!\n  \n  저는 대통령이 되겠습니다. 우리나라 대통령이 되겠습니다. 소수 특권층의 나라가 아니라 보통사람들이 주인인 ‘우리나라’, 네 편 내 편 편가르지 않고 함께 가는 우리나라, ‘우리’라는 말이 조금도 부끄럽지 않은, 진정한 ‘우리나라’의 대통령이 되겠습니다.\n\n지금까지 우리 보통사람들은 날지도 울지도 못하는 새였습니다. 나라의 주인으로 행세하지 못했고, 주인으로 대접받지 못했습니다. 나서서 말도 하지 못했습니다. 이제 몸을 일으켜 날아야 합니다. 당당하게 말하고 정치에 참여해야 합니다.\n\n제가 추구하는 ‘우리나라’는 정치인에게 맡겨놓는 나라가 아니라 시민이 직접 정치와 정책과정에 참여하는 나라입니다. 저는 시민과 동행하는 정치를 하고 싶습니다. 제가 추구하는 ‘우리나라’는 특권과 불평등의 나라가 아니라, 보통사람들이 함께 기회를 가지는 공평하고 정의로운 나라입니다.\n\n이제 권력과 돈을 가진 집단이 나라를 그들 마음대로 움직이던 시대는 끝났습니다. 힘없는 사람들에게 끝없이 희생을 강요하던 낡은 경제, 낡은 정치, 낡은 권력도 모두 끝났습니다. 오늘 저 문재인은 우리나라를 우리 모두의 나라로 선언합니다.\n\n국민이 모두 아픕니다.\n\n제가 높이 날고 크게 울겠다고 결심한 이유는 보통사람들의 삶이 너무 고달프고, 우리가 처한 현실이 너무도 
# ...

# %%
import re                                 #불필요한 문자 제거, [^가-힣]은 한글이 아닌 모든 문자를 의미하는 정규 표현식임
moon=re.sub('[^가-힣]',' ',moon)
moon
# Out:
# '정권교체 하겠습니다    정치교체 하겠습니다    시대교체 하겠습니다        불비불명       이라는 고사가 있습니다  남쪽 언덕 나뭇가지에 앉아   년 동안 날지도 울지도 않는 새  그러나 그 새는 한번 날면 하늘 끝까지 날고  한번 울면 천지를 뒤흔듭니다   그 동안 정치와 거리를 둬 왔습니다  그러나 암울한 시대가 저를 정치로 불러냈습니다  더 이상 남쪽 나뭇가지에 머무를 수 없었습니다  이제 저는 국민과 함께 높이 날고 크게 울겠습니다  오늘 저는 제  대 대통령선거 출마를 국민 앞에 엄숙히 선언합니다     우리나라 대통령 이 되겠습니다    존경하는 국민 여러분       저는 대통령이 되겠습니다  우리나라 대통령이 되겠습니다  소수 특권층의 나라가 아니라 보통사람들이 주인인  우리나라   네 편 내 편 편가르지 않고 함께 가는 우리나라   우리 라는 말이 조금도 부끄럽지 않은  진정한  우리나라 의 대통령이 되겠습니다   지금까지 우리 보통사람들은 날지도 울지도 못하는 새였습니다  나라의 주인으로 행세하지 못했고  주인으로 대접받지 못했습니다  나서서 말도 하지 못했습니다  이제 몸을 일으켜 날아야 합니다  당당하게 말하고 정치에 참여해야 합니다   제가 추구하는  우리나라 는 정치인에게 맡겨놓는 나라가 아니라 시민이 직접 정치와 정책과정에 참여하는 나라입니다  저는 시민과 동행하는 정치를 하고 싶습니다  제가 추구하는  우리나라 는 특권과 불평등의 나라가 아니라  보통사람들이 함께 기회를 가지는 공평하고 정의로운 나라입니다   이제 권력과 돈을 가진 집단이 나라를 그들 마음대로 움직이던 시대는 끝났습니다  힘없는 사람들에게 끝없이 희생을 강요하던 낡은 경제  낡은 정치  낡은 권력도 모두 끝났습니다  오늘 저 문재인은 우리나라를 우리 모두의 나라로 선언합니다   국민이 모두 아픕니다   제가 높이 날고 크게 울겠다고 결심한 이유는 보통사람들의 삶이 너무 고달프고  우리가 처한 현실이 너무도 엄중하기 때문입니다  근본적인 혁신  거대한
# ...

# %%
import konlpy                                                         #hannanum 만듦
hannanum = konlpy.tag.Hannanum()
hannanum.nouns("대한민국의 영토는 한반도와 그 부속도서로 한다")       #명사 추출
# Out:
# ['대한민국', '영토', '한반도', '부속도서']

# %%
nouns=hannanum.nouns(moon)                         #연설문에서 명사 추출
nouns
# Out:
# ['정권교체',
#  '정치교체',
#  '시대교체',
#  '불비불명',
#  '고사',
#  '남쪽',
#  '언덕',
#  '나뭇가지',
#  '년',
#  '동안',
#  '새',
#  '한번',
#  '하늘',
#  '끝',
#  '한번',
#  '천지',
#  '동안',
#  '정치',
#  '거리',
#  '암울한',
#  '시대',
#  '저',
#  '정치',
#  '이상',
#  '남쪽',
#  '나뭇가지',
#  '수',
#  '저',
#  '국민',
#  '오늘',
#  '저',
#  '저',
#  '대',
#  '대통령선거',
#  '출마',
#  '국민',
#  '앞',
#  '선언',
#  '우리나라',
#  '대통령',
#  '존경',
#  '국민',
#  '여러분',
#  '저',
#  '대통령',
#  '우리나라',
#  '대통령',
#  '소수',
#  '특권층',
#  '나라',
#  '보통사람들',
#  '주인',
#  '우리나라',
#  '네',
#  '편',
#  '내',
#  '편',
#  '편가르지',
#  '우리나라',
#  '우리',
#  '라',
#  '말',
#  '진정한',
#  '우리나라',
#  '의',
#  '대통령',
#  '지금',
#  '우리',
#  '보통사람들',
#  '새',
#  '나라',
#  '주인',
#  '행세',
#  '주인',
#  '대접',
#  '말',
#  '몸',
#  '당당',
#  '말',
#  '정치',
#  '참여',
#  '저',
#  '추구',
#  '우리나라',
#  '정치인',
#  '나라',
#  '시민',
#  '정치',
#  '정책과정',
#  '참여',
#  '나라',
#  '저',
#  '시민',
#  '동행',
#  '정치',
#  '저',
#  '추구',
#  '우리나라',
#  '특권',
#  '불평등',
#  '나라',
#  '보통사람들',
#  '기회',
#  '공평',
#  '정의로운',
#  '나라',
#  '권력',
#  '돈',
# ...

# %%
df_word=pd.DataFrame({'word':nouns})
df_word                 #데이터 프레임으로
# Out:
#       word
# 0     정권교체
# 1     정치교체
# 2     시대교체
# 3     불비불명
# 4       고사
# ...    ...
# 1408    모두
# 1409    주인
# 1410   진정한
# 1411  우리나라
# 1412   대통령
#
# [1413 rows x 1 columns]

# %%
df_word['count']=df_word['word'].str.len()
df_word      #글자 수 추가
# Out:
#       word  count
# 0     정권교체      4
# 1     정치교체      4
# 2     시대교체      4
# 3     불비불명      4
# 4       고사      2
# ...    ...    ...
# 1408    모두      2
# 1409    주인      2
# 1410   진정한      3
# 1411  우리나라      4
# 1412   대통령      3
#
# [1413 rows x 2 columns]

# %%
df_word=df_word.query('count>=2')
df_word.sort_values('count')
# Out:
#           word  count
# 1402        국민      2
# 1401        나라      2
# 1399        권력      2
# 1398        겸손      2
# 1395        세상      2
# ...        ...    ...
# 1143    기초노령연금      6
# 1268    군사대결지대      6
# 173     성적스트레스      6
# 1055  국가일자리위원회      8
# 978   고용영향평가제도      8
#
# [1187 rows x 2 columns]

# %%
df_word=df_word.groupby('word',as_index=False).agg(n=('word','count')).sort_values('n',ascending=False)
df_word         #단어 빈도 구함
# Out:
#      word   n
# 462   일자리  19
# 153    나라  19
# 116    국민  18
# 422    우리  17
# 198   대통령  12
# ..    ...  ..
# 324  석유시대   1
# 322  서민경제   1
# 321    서로   1
# 320  생활임금   1
# 300    사병   1
#
# [710 rows x 2 columns]

# %%
top20=df_word.head(20)         #단어 빈도 상위 20개 추출
top20
# Out:
#      word   n
# 462   일자리  19
# 153    나라  19
# 116    국민  18
# 422    우리  17
# 198   대통령  12
# 202  대한민국  11
# 693    확대  11
# 423  우리나라  10
# 525    정치  10
# 304    사회   9
# 298    사람   9
# 332    성장   9
# 646    평화   8
# 266  복지국가   8
# 265    복지   8
# 308    산업   7
# 609    추진   7
# 517    정부   7
# 48     경쟁   6
# 339    세상   6

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
plt.rc('font', family='NanumBarunGothic')
plt.rcParams.update({'font.family' :'NanumBarunGothic',   #한글폰트
                     'figure.dpi'  :'120',                #해상도
                     'figure.figsize':[6.5,6]})           #가로 세로 크기
sns.barplot(data=top20, y='word',x='n',hue='word')        #막대그래프, 색깔별
# Out:
# <Axes: xlabel='n', ylabel='word'>
